# %% [markdown]
# # **C3a**

# %%
# Necesarias para manejo de índices
# !pip install rtree -q
# !pip install pygeos -q

# !pip install geopandas -q
# Out:
#      |████████████████████████████████| 1.0 MB 14.9 MB/s
#      |████████████████████████████████| 2.1 MB 13.3 MB/s
#      |████████████████████████████████| 1.0 MB 13.3 MB/s
#      |████████████████████████████████| 6.3 MB 71.8 MB/s
#      |████████████████████████████████| 16.7 MB 63.1 MB/s

# %%
import geopandas as gpd

# %%
terremotos = gpd.read_file("terremotos.csv")

# %%
terremotos.head(10)
# Out:
#          Date      Time Latitude Longitude        Type  Depth Magnitude  \
# 0  1965-01-02  13:44:18   19.246   145.616  Earthquake  131.6       6.0
# 1  1965-01-04  11:29:49    1.863   127.352  Earthquake   80.0       5.8
# 2  1965-01-05  18:05:58  -20.579  -173.972  Earthquake   20.0       6.2
# 3  1965-01-08  18:49:43  -59.076   -23.557  Earthquake   15.0       5.8
# 4  1965-01-09  13:32:50   11.938   126.427  Earthquake   15.0       5.8
# 5  1965-01-10  13:36:32  -13.405   166.629  Earthquake   35.0       6.7
# 6  1965-01-12  13:32:25   27.357    87.867  Earthquake   20.0       5.9
# 7  1965-01-15  23:17:42  -13.309   166.212  Earthquake   35.0       6.0
# 8  1965-01-16  11:32:37  -56.452   -27.043  Earthquake   95.0       6.0
# 9  1965-01-17  10:43:17  -24.563   178.487  Earthquake  565.0       5.8
#
#                 ID geometry
# 0     ISCGEM860706     None
# 1     ISCGEM860737     None
# 2     ISCGEM860762     None
# 3     ISCGEM860856     None
# 4     ISCGEM860890     None
# ...

# %%
gdf = gpd.GeoDataFrame(
    terremotos, geometry=gpd.points_from_xy(terremotos.Longitude, terremotos.Latitude))
terremotos = gdf
display(terremotos.head(10))
# Out:
#          Date      Time Latitude Longitude        Type  Depth Magnitude  \
# 0  1965-01-02  13:44:18   19.246   145.616  Earthquake  131.6       6.0
# 1  1965-01-04  11:29:49    1.863   127.352  Earthquake   80.0       5.8
# 2  1965-01-05  18:05:58  -20.579  -173.972  Earthquake   20.0       6.2
# 3  1965-01-08  18:49:43  -59.076   -23.557  Earthquake   15.0       5.8
# 4  1965-01-09  13:32:50   11.938   126.427  Earthquake   15.0       5.8
# 5  1965-01-10  13:36:32  -13.405   166.629  Earthquake   35.0       6.7
# 6  1965-01-12  13:32:25   27.357    87.867  Earthquake   20.0       5.9
# 7  1965-01-15  23:17:42  -13.309   166.212  Earthquake   35.0       6.0
# 8  1965-01-16  11:32:37  -56.452   -27.043  Earthquake   95.0       6.0
# 9  1965-01-17  10:43:17  -24.563   178.487  Earthquake  565.0       5.8
#
#                 ID                      geometry
# 0     ISCGEM860706    POINT (145.61600 19.24600)
# 1     ISCGEM860737     POINT (127.35200 1.86300)
# ...
